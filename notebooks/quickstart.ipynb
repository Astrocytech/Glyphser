# %% [markdown]
# # Glyphser Quickstart Notebook
#
# This notebook runs a deterministic parity/divergence proof flow.

# %%
import json
from pathlib import Path

from examples.proof_demo import main as run_demo

rc = run_demo()
print("exit_code:", rc)

# %%
summary_path = Path("evidence/demo/summary.json")
summary = json.loads(summary_path.read_text(encoding="utf-8"))
summary

# %% [markdown]
# ## Expected
#
# - `same_seed_match` is `true`
# - `different_seed_diverges` is `true`
# - Evidence manifests are in `evidence/demo/`
